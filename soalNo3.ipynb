# %%
import numpy as np
import pandas as pd
from apyori import apriori

# %%
store_data = pd.read_excel('C:/Intel/uas/dataset_soal No. 3.xls')

# %%
store_data.head()
# Out:
#             Item1              Item2         Item3              Item4  \
# 0         burgers          meatballs          eggs     low fat yogurt
# 1         chutney     low fat yogurt           NaN  whole wheat pasta
# 2          turkey  whole wheat pasta  french fries               soup
# 3   mineral water               soup   light cream  frozen vegetables
# 4  low fat yogurt  frozen vegetables     spaghetti       french fries
#
#           Item5          Item6            Item7              Item8  \
# 0           NaN  mineral water           salmon     low fat yogurt
# 1  french fries  mineral water           salmon  whole wheat pasta
# 2   light cream        shallot              NaN               soup
# 3     spaghetti      green tea              NaN  frozen vegetables
# 4          eggs      chocolate  frozen smoothie       french fries
#
#           Item9         Item10
# 0           NaN  mineral water
# 1  french fries  mineral water
# 2   light cream        shallot
# ...

# %%
store_data.tail()
# Out:
#                   Item1         Item2            Item3        Item4  \
# 2049            burgers          eggs     french fries   fresh tuna
# 2050            burgers          eggs  frozen smoothie  french wine
# 2051  whole wheat pasta          cake           melons    champagne
# 2052        ground beef  tomato sauce        spaghetti     red wine
# 2053            burgers          eggs  frozen smoothie         milk
#
#           Item5         Item6                Item7          Item8  \
# 2049  spaghetti     olive oil  clothes accessories         turkey
# 2050       eggs  french fries         energy drink   french fries
# 2051   pancakes    light mayo                 soup      chocolate
# 2052      honey      hot dogs               turkey  herb & pepper
# 2053      bacon          eggs         french fries  mineral water
#
#                   Item9         Item10
# 2049               eggs   french fries
# 2050                NaN      chocolate
# ...

# %%
store_data.shape
# Out:
# (2054, 10)

# %%
records = []
for i in range(0, 22):
    records.append([str(store_data.values[i,j]) for j in range(0,6)])

# %%
association_rules = apriori(records, min_support=0.2, min_confidence=0.2, min_lift=0.2, min_lenght=2)
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 13

# %%
print(association_results[0])
# Out:
# RelationRecord(items=frozenset({'burgers'}), support=0.2727272727272727, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'burgers'}), confidence=0.2727272727272727, lift=1.0)])

# %%
results =[]
for item in association_results:
    pair = item[0]
    items = [x for x in pair]
    
    value0 = str(items[0])
    value1 = str(items[1])
    value2 = str(item[1])[:6]
    value3 = str(item[2][0][2])[:6]
    value4 = str(item[2][0][3])[:6]
    
    rows = (value0,value1,value2,value3,value4,)
    results.append(rows)
    label = ['title1', 'title2','support','confidence','lift']
    store_suggestion = pd.DataFrame.from_records(results,columns=label)
    print(store_suggestion)
# Out:
#   title1 title2 support confidence  lift
# 0   Wine  Bread  0.4545     0.9090  1.25
#   title1 title2 support confidence    lift
# 0   Wine  Bread  0.4545     0.9090    1.25
# 1   Milk  Apple  0.4090     0.8181  1.2000
#   title1 title2 support confidence    lift
# 0   Wine  Bread  0.4545     0.9090    1.25
# 1   Milk  Apple  0.4090     0.8181  1.2000
# 2  Bread  Chips  0.4090     0.9000  1.3200
#   title1 title2 support confidence    lift
# 0   Wine  Bread  0.4545     0.9090    1.25
# 1   Milk  Apple  0.4090     0.8181  1.2000
# 2  Bread  Chips  0.4090     0.9000  1.3200
# 3  Bread   Milk     0.5     0.7333  1.2410
#   title1 title2 support confidence    lift
# 0   Wine  Bread  0.4545     0.9090    1.25
# 1   Milk  Apple  0.4090     0.8181  1.2000
# 2  Bread  Chips  0.4090     0.9000  1.3200
# 3  Bread   Milk     0.5     0.7333  1.2410
# 4   Wine  Bread  0.4545     0.9090    1.25
#   title1 title2 support confidence    lift
# 0   Wine  Bread  0.4545     0.9090    1.25
# ...

# %%
store_data.describe()
# Out:
#                 Item1         Item2         Item3         Item4         Item5  \
# count            2054          1987          2009          1935          1881
# unique            102            94            85            75            64
# top     mineral water  french fries  french fries  french fries  french fries
# freq              172           205           173           233           253
#
#                Item6         Item7          Item8    Item9        Item10
# count           1873          1685           1659     1372          1457
# unique            62            63             55       49            44
# top     french fries  french fries  mineral water  avocado  energy drink
# freq             264           200            170      163           162

# %%
store_data.to_excel('C:/Intel/uas/data_output.xls')
